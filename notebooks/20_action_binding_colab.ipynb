# %% [markdown]
# # Menia — apprentissage des valeurs et codes d’action
#
# Colab 20 : six adaptateurs, 384 mises à jour, 6 912 décisions réservées au test. Conserver le runtime A100 et l’environnement Menia. Deux entraînements appariés sur trois initialisations ; une seule tentative. Le choix sous risque public est un contrôle fonctionnel, pas une preuve de conscience.
#
# [Protocole fixé](https://github.com/speed25200-cyber/Menia/blob/6d9c1c6ff8b8f15fb7ea63c23c379d5d9f44f781/docs/ACTION_BINDING_PROTOCOL.md).

# %%
import hashlib, importlib.util, pathlib, urllib.request
REVISION = "6d9c1c6ff8b8f15fb7ea63c23c379d5d9f44f781"
url = f"https://raw.githubusercontent.com/speed25200-cyber/Menia/{REVISION}/scripts/colab_action_binding_launcher.py"
data = urllib.request.urlopen(url, timeout=60).read()
assert hashlib.sha256(data).hexdigest() == "7b8eecdb5ee16dfefc0db9dd53275da25c739f1cb3d63fd35ba00ffbe52de340", "Launcher changed"
path = pathlib.Path("/content/menia-action-binding-launcher.py")
path.write_bytes(data)
spec = importlib.util.spec_from_file_location("menia_action_binding_launcher", path)
module = importlib.util.module_from_spec(spec)
spec.loader.exec_module(module)
result = module.launch_action_binding(REVISION)
print(result)

# %%
from google.colab import files
files.download("/content/menia-liaison-actions.zip")
