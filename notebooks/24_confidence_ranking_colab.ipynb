# %% [markdown]
# # Menia — classement de confiance dans les catégories
#
# Colab 24 : neuf adaptateurs appariés, 1 296 mises à jour,
# 1 152 nouvelles questions, 4 608 générations et 18 432 jugements.
# Même capacité et mêmes exemples ; trois objectifs d'apprentissage.
# Tous les adaptateurs sont figés avant la première question d'évaluation.
#
# Conserver le runtime A100 Menia et son environnement Python. Exécuter
# le premier bloc une seule fois. Une tentative existante est conservée.
# Les treize contrôles logiciels ne sont pas des résultats de Menia.
# La conscience et la nouveauté scientifique ne sont pas établies.
#
# [Protocole fixé](https://github.com/speed25200-cyber/Menia/blob/4cbce2edea430cc7e4df52546d448e91a7c98629/docs/CONFIDENCE_RANKING_PROTOCOL.md).

# %%
import hashlib, importlib.util, pathlib, urllib.request
REVISION = "4cbce2edea430cc7e4df52546d448e91a7c98629"
url = f"https://raw.githubusercontent.com/speed25200-cyber/Menia/{REVISION}/scripts/colab_confidence_ranking_launcher.py"
data = urllib.request.urlopen(url, timeout=60).read()
assert hashlib.sha256(data).hexdigest() == "144f1d0f348ea5c880a5fb6f34d4a1b7429a1e0d499379ed565c96bd9d8271fe", "Launcher changed"
path = pathlib.Path("/content/menia-confidence-ranking-v1-launcher.py")
path.write_bytes(data)
spec = importlib.util.spec_from_file_location("menia_confidence_ranking_launcher", path)
module = importlib.util.module_from_spec(spec)
spec.loader.exec_module(module)
result = module.launch_confidence_ranking(REVISION)
print(result)

# %%
from google.colab import files
files.download("/content/menia-classement-confiance-v1.zip")
