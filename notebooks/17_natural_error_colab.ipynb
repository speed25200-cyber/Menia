# %% [markdown]
# # Menia — prévision des erreurs naturelles
#
# Colab 17 : 3 456 questions, trois répétitions d’ajustement des lecteurs, Qwen3-4B de base sans adaptation. Conserver le runtime A100 et l’environnement Menia installé ; aucun journal ni poids adapté des anciens essais n’est requis. La prévision est enregistrée avant le premier token. Les huit tests passent avant collecte. Une tentative existante est conservée et bloque un second lancement. Ce protocole teste un lecteur externe, pas une conscience.
#
# [Protocole fixé](https://github.com/speed25200-cyber/Menia/blob/7997c23a417abfde194c3b7281e854ea1173d64c/docs/NATURAL_ERROR_PROTOCOL.md).

# %%
import hashlib, importlib.util, pathlib, urllib.request
REVISION = "7997c23a417abfde194c3b7281e854ea1173d64c"
url = f"https://raw.githubusercontent.com/speed25200-cyber/Menia/{REVISION}/scripts/colab_natural_error_launcher.py"
data = urllib.request.urlopen(url, timeout=60).read()
assert hashlib.sha256(data).hexdigest() == "ee5e4ec83ef588c9cb5fe2494c6ac3decc8416ec85154ff6aac19fa35b53b214", "Launcher changed"
path = pathlib.Path("/content/menia-natural-error-launcher.py")
path.write_bytes(data)
spec = importlib.util.spec_from_file_location("menia_natural_error_launcher", path)
module = importlib.util.module_from_spec(spec)
spec.loader.exec_module(module)
result = module.launch_natural_errors(REVISION)
print(result)

# %%
from google.colab import files
files.download("/content/menia-erreurs-naturelles.zip")
