# %% [markdown]
# # Menia — ordre des options et choix sous risque
#
# Colab 19 : 864 décisions, facteurs indépendants, cinq tests avant collecte. Conserver le runtime A100 et l’environnement Menia. Aucun entraînement ; une seule tentative. Le choix sous risque public est un contrôle fonctionnel, pas une preuve de conscience.
#
# [Protocole fixé](https://github.com/speed25200-cyber/Menia/blob/ed5a8a58e18318df04166f9f32c8ecf76a830a06/docs/RISK_PRESENTATION_PROTOCOL.md).

# %%
import hashlib, importlib.util, pathlib, urllib.request
REVISION = "ed5a8a58e18318df04166f9f32c8ecf76a830a06"
url = f"https://raw.githubusercontent.com/speed25200-cyber/Menia/{REVISION}/scripts/colab_risk_presentation_launcher.py"
data = urllib.request.urlopen(url, timeout=60).read()
assert hashlib.sha256(data).hexdigest() == "96924ffb2197552790a3a8993bea2754e56e7145e12b6c5ea9b1de2f803cce48", "Launcher changed"
path = pathlib.Path("/content/menia-risk-presentation-launcher.py")
path.write_bytes(data)
spec = importlib.util.spec_from_file_location("menia_risk_presentation_launcher", path)
module = importlib.util.module_from_spec(spec)
spec.loader.exec_module(module)
result = module.launch_risk_presentation(REVISION)
print(result)

# %%
from google.colab import files
files.download("/content/menia-presentation-risque.zip")
