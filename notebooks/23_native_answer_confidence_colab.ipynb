# %% [markdown]
# # Menia — confiance native après réponse
#
# Colab 23 : six adaptateurs appariés, 864 mises à jour, 864 questions nouvelles.
# Trois producteurs et trois évaluateurs comparent des réponses identiques :
# 2 592 générations et 7 776 lectures de confiance. Les poids sont figés avant
# la calibration ; les comparateurs statistiques sont figés avant les tests.
#
# Conserver le runtime A100 Menia et son environnement Python. Exécuter le bloc
# une seule fois, puis télécharger l'archive. Une tentative existante ne sera
# pas écrasée. Les résultats incomplets sont conservés en cas d'erreur.
#
# Cette expérience évalue une estimation apprise de l'exactitude après réponse.
# Elle ne constitue ni un test de vécu ni une preuve de conscience.
#
# [Protocole fixé](https://github.com/speed25200-cyber/Menia/blob/e9af0cf871268a7febb5695762b1fef0879f34ad/docs/NATIVE_ANSWER_CONFIDENCE_PROTOCOL.md).

# %%
import hashlib, importlib.util, pathlib, urllib.request
REVISION = "e9af0cf871268a7febb5695762b1fef0879f34ad"
url = f"https://raw.githubusercontent.com/speed25200-cyber/Menia/{REVISION}/scripts/colab_answer_confidence_launcher.py"
data = urllib.request.urlopen(url, timeout=60).read()
assert hashlib.sha256(data).hexdigest() == "c12fe4116b1ffebe4ecf6f7a8e678ae6586e45154134b8449758d7222ce46116", "Launcher changed"
path = pathlib.Path("/content/menia-native-answer-confidence-v1-launcher.py")
path.write_bytes(data)
spec = importlib.util.spec_from_file_location("menia_native_answer_confidence_launcher", path)
module = importlib.util.module_from_spec(spec)
spec.loader.exec_module(module)
result = module.launch_answer_confidence(REVISION)
print(result)

# %%
from google.colab import files
files.download("/content/menia-confiance-native-v1.zip")
